# %%
# Core data stack
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# import sqlalchemy as sa
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_error, r2_score, classification_report, confusion_matrix
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier

sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

# Step 1: Install SQLAlchemy (only once per cluster)
# %pip install SQLAlchemy psycopg2-binary
# %restart_python

# %%
import pandas as pd
import sqlalchemy as sa

# Correct connection string
engine = sa.create_engine("postgresql://user:pwd@host:5432/silverdata")

# Load table
df = pd.read_sql_table("orders", con=engine)

print(df.shape)
print(df.head())

# %%
# ------------------------------------------------------------------
# Adjust the connection string to your DB (Postgres, Redshift, Snowflake…)
# ------------------------------------------------------------------
engine = sa.create_engine(
    "postgresql://<user>:<pwd>@<host>:<port>/silverdata"
)

# Pull the whole table (or a sample if it’s huge)
df = pd.read_sql_table("orders", con=engine)

# Quick sanity check
print(df.shape)
print(df.head())
